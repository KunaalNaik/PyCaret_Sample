# %% [markdown]
# ## 1. Getting Data

# %%
from pycaret.datasets import get_data
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %% [markdown]
# ## 2. Setting up Environment

# %%
from pycaret.classification import *
exp1 = setup(diabetes, target = 'Class variable')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row0_col1" class="data row0 col1" >6667</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row3_col1" class="data row3 col1" >(768, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row6_col1" class="data row6 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row10_col1" class="data row10 col1" >(768, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row11_col1" class="data row11 col1" >(537, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row12_col1" class="data row12 col1" >(231, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_b55e3222_c0d7_11ea_b851_983b8f9db0c4row18_col1" class="data row18 col1" >None</td>
#             </tr>
#             <

# %% [markdown]
# ## 3. Compare Models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4 th {
#           text-align: left;
#     }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row2_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row10_col0 {
#             text-align:  left;
#         }    #T_c9abfc02_c0d7_11ea_abef_983b8f9db0c4row10

# %% [markdown]
# ## 4. Create Models

# %%
adaboost = create_model('ada')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8594  0.6842  0.6842  0.6842  0.5128
# 1       0.7407  0.7850  0.5789  0.6471  0.6111  0.4176
# 2       0.8148  0.8707  0.8421  0.6957  0.7619  0.6126
# 3       0.7407  0.7549  0.5263  0.6667  0.5882  0.4028
# 4       0.6667  0.7406  0.4211  0.5333  0.4706  0.2322
# 5       0.6481  0.7444  0.3158  0.5000  0.3871  0.1576
# 6       0.7222  0.8030  0.5263  0.6250  0.5714  0.3682
# 7       0.7925  0.8079  0.6111  0.7333  0.6667  0.5178
# 8       0.6981  0.7825  0.6111  0.5500  0.5789  0.3447
# 9       0.7925  0.7984  0.5000  0.8182  0.6207  0.4890
# Mean    0.7394  0.7947  0.5617  0.6453  0.5941  0.4055
# SD      0.0533  0.0418  0.1362  0.0924  0.1007  0.1307

# %% [markdown]
# ## 5. Tune Models

# %%
tuned_adaboost = tune_model('ada')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8752  0.6316  0.7059  0.6667  0.5008
# 1       0.7222  0.8075  0.4737  0.6429  0.5455  0.3520
# 2       0.8704  0.9248  0.8947  0.7727  0.8293  0.7257
# 3       0.7778  0.8211  0.5789  0.7333  0.6471  0.4882
# 4       0.6296  0.7233  0.4211  0.4706  0.4444  0.1680
# 5       0.6667  0.7534  0.2632  0.5556  0.3571  0.1692
# 6       0.7222  0.8241  0.4211  0.6667  0.5161  0.3350
# 7       0.7925  0.8310  0.5556  0.7692  0.6452  0.5038
# 8       0.7358  0.8016  0.5556  0.6250  0.5882  0.3948
# 9       0.7547  0.8381  0.3889  0.7778  0.5185  0.3776
# Mean    0.7450  0.8200  0.5184  0.6720  0.5758  0.4015
# SD      0.0639  0.0536  0.1624  0.0964  0.1246  0.1578

# %% [markdown]
# ## 6. Ensemble Models

# %%
# creating a decision tree model
dt = create_model('dt')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.6852  0.6489  0.5263  0.5556  0.5405  0.3014
# 1       0.7037  0.7113  0.7368  0.5600  0.6364  0.3941
# 2       0.7222  0.7015  0.6316  0.6000  0.6154  0.3982
# 3       0.6481  0.5962  0.4211  0.5000  0.4571  0.1997
# 4       0.6852  0.6489  0.5263  0.5556  0.5405  0.3014
# 5       0.7037  0.6391  0.4211  0.6154  0.5000  0.2998
# 6       0.7037  0.6992  0.6842  0.5652  0.6190  0.3802
# 7       0.7547  0.6929  0.5000  0.6923  0.5806  0.4136
# 8       0.7736  0.7746  0.7778  0.6364  0.7000  0.5211
# 9       0.6981  0.6500  0.5000  0.5625  0.5294  0.3083
# Mean    0.7078  0.6763  0.5725  0.5843  0.5719  0.3518
# SD      0.0339  0.0472  0.1207  0.0508  0.0685  0.0837

# %%
# ensembling a trained dt model
dt_bagged = ensemble_model(dt)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8218  0.4737  0.8182  0.6000  0.4609
# 1       0.6852  0.7211  0.3684  0.5833  0.4516  0.2463
# 2       0.7778  0.8436  0.6842  0.6842  0.6842  0.5128
# 3       0.7593  0.8173  0.5263  0.7143  0.6061  0.4384
# 4       0.6481  0.7008  0.4737  0.5000  0.4865  0.2192
# 5       0.7222  0.7263  0.4211  0.6667  0.5161  0.3350
# 6       0.7222  0.8038  0.5263  0.6250  0.5714  0.3682
# 7       0.7547  0.7833  0.4444  0.7273  0.5517  0.3961
# 8       0.6604  0.7794  0.3333  0.5000  0.4000  0.1762
# 9       0.7736  0.8563  0.3889  0.8750  0.5385  0.4165
# Mean    0.7281  0.7854  0.4640  0.6694  0.5406  0.3570
# SD      0.0464  0.0509  0.0951  0.1169  0.0779  0.1055

# %% [markdown]
# ## 7. Plot Model

# %%
# create a model
adaboost = create_model('ada')
# AUC plot
plot_model(adaboost, plot = 'auc')
# Decision Boundary
plot_model(adaboost, plot = 'boundary')
# Precision Recall Curve
plot_model(adaboost, plot = 'pr')
# Validation Curve
plot_model(adaboost, plot = 'vc')

# %%
evaluate_model(adaboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## 8. Interpret Model

# %%
# create a model
xgboost = create_model('xgboost')
# summary plot
interpret_model(xgboost)
# correlation plot
interpret_model(xgboost, plot = 'correlation')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7593  0.8391  0.6842  0.6500  0.6667  0.4785
# 1       0.7593  0.8030  0.6316  0.6667  0.6486  0.4658
# 2       0.7963  0.8707  0.7895  0.6818  0.7317  0.5689
# 3       0.7778  0.8045  0.5789  0.7333  0.6471  0.4882
# 4       0.6667  0.7398  0.5263  0.5263  0.5263  0.2692
# 5       0.6852  0.8030  0.3684  0.5833  0.4516  0.2463
# 6       0.7963  0.8496  0.6842  0.7222  0.7027  0.5479
# 7       0.7736  0.8143  0.5000  0.7500  0.6000  0.4508
# 8       0.7925  0.8413  0.7778  0.6667  0.7179  0.5553
# 9       0.7358  0.8429  0.3889  0.7000  0.5000  0.3399
# Mean    0.7543  0.8208  0.5930  0.6680  0.6193  0.4411
# SD      0.0433  0.0347  0.1401  0.0654  0.0920  0.1108

# %%
interpret_model(xgboost, plot = 'reason', observation = 0)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iCJG01DH09EN1NPINNHRB'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -0.7174868583679199, "outValue": -1.9376672506332397, "link": "identity", "featureNames": ["Plasma glucose concentration a 2 hours in an oral glucose tolerance test", "Diastolic blood pressure (mm Hg)", "Triceps skin fold thickness (mm)", "2-Hour serum insulin (mu U/ml)", "Body mass index (weight in kg/(height in m)^2)", "Diabetes pedigree function", "Age (years)", "Number of times pregnant_0", "Number of times pregnant_1", "Number of times pregnant_10", "Number of times pregnant_11", "Number of times pregnant_12", "Number of times pregnant_13", "Number of times pregnant_14", "Number of times pregnant_15", "Number of times pregnant_17", "Number of times pregnant_2", "Number of times pregnant_3", "Number of times pregnant_4", "Number of times pregnant_5", "Number of times pregnant_6", "Number of times pregnant_7", "Number of times pregnant_8", "Number of times pregnant_9"], "features": {"0": {"effect": -1.0606976747512817, "value": 90.0}, "1": {"effect": -0.18202978372573853, "value": 88.0}, "2": {"effect": 0.08675236999988556, "value": 47.0}, "3": {"effect": -0.2935713231563568, "value": 54.0}, "4": {"effect": 0.030348023399710655, "value": 37.7}, "5": {"effect": 0.0372958779335022, "value": 0.36200000000000004}, "6": {"effect": 0.2053038477897644, "value": 29.0}, "8": {"effect": -0.010865673422813416, "value": 0.0}, "10": {"effect": -0.003276477800682187, "value": 0.0}, "16": {"effect": 0.0017467031721025705, "value": 0.0}, "19": {"effect": -0.0064334566704928875, "value": 0.0}, "20": {"effect": 0.00969610083848238, "value": 0.0}, "21": {"effect": -0.017186859622597694, "value": 0.0}, "22": {"effect": -0.007785730063915253, "value": 0.0}, "23": {"effect": -0.009476248174905777, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iCJG01DH09EN1NPINNHRB')
#   );
# </script>

# %% [markdown]
# ## 9. Predict Model

# %%
# create a model
rf = create_model('rf')
# predict test / hold-out dataset
rf_holdout_pred = predict_model(rf)
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0  Random Forest Classifier    0.7316  0.7843  0.5432  0.6377  0.5867  0.3898

# %%
predictions = predict_model(rf, data = diabetes)

# %%
predictions
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# 766                                                126
# 767                                                 93
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                  72                                35
# 1                                  66                                29
# 2                                  64                                 0
# 3                                  66                                23
# 4                                  40                                35
# ..                                ...                               ...
# 763                                76                                48
# 764                                70                                27
# 765                                72                                23
# 766                                60                                 0
# 767                                70                                31
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                94
# 4                               168
# ..                              ...
# 763                             180
# 764                               0
# 765                             112
# 766                               0
# 767                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                              33.6
# 1                                              26.6
# 2                                              23.3
# 3                                              28.1
# 4                                              43.1
# ..                                              ...
# 763                                            32.9
# 764                                            36.8
# 765                                            26.2
# 766                                            30.1
# 767                                            30.4
#
#      Diabetes pedigree function  Age (years)  Class variable  Label  Score
# 0                         0.627           50               1      1    0.9
# 1                         0.351           31               0      0    0.0
# 2                         0.672           32               1      1    0.8
# 3                         0.167           21               0      0    0.0
# 4                         2.288           33               1      1    0.9
# ..                          ...          ...             ...    ...    ...
# 763                       0.171           63               0      0    0.2
# 764                       0.340           27               0      0    0.1
# 765                       0.245           30               0      0    0.1
# 766                       0.349           47               1      0    0.4
# 767                       0.315           23               0      0    0.0
#
# [768 rows x 11 columns]

# %% [markdown]
# ## 10. Deploy Model

# %%
#Not Working
deploy_model(model = rf, model_name = 'rf_aws', platform = 'aws', 
             authentication =  {'bucket'  : 'pycaret-test'})

# %% [markdown]
# ## 11. Save Model / Save Experiment

# %%
# creating model
adaboost = create_model('ada')
# saving model
save_model(adaboost, model_name = 'ada_for_deployment')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8594  0.6842  0.6842  0.6842  0.5128
# 1       0.7407  0.7850  0.5789  0.6471  0.6111  0.4176
# 2       0.8148  0.8707  0.8421  0.6957  0.7619  0.6126
# 3       0.7407  0.7549  0.5263  0.6667  0.5882  0.4028
# 4       0.6667  0.7406  0.4211  0.5333  0.4706  0.2322
# 5       0.6481  0.7444  0.3158  0.5000  0.3871  0.1576
# 6       0.7222  0.8030  0.5263  0.6250  0.5714  0.3682
# 7       0.7925  0.8079  0.6111  0.7333  0.6667  0.5178
# 8       0.6981  0.7825  0.6111  0.5500  0.5789  0.3447
# 9       0.7925  0.7984  0.5000  0.8182  0.6207  0.4890
# Mean    0.7394  0.7947  0.5617  0.6453  0.5941  0.4055
# SD      0.0533  0.0418  0.1362  0.0924  0.1007  0.1307
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ### Save Experiment

# %%
save_experiment(experiment_name = 'my_first_experiment')

# %% [markdown]
# ### Load Experiment

# %% [markdown]
# 💡 You can load saved model and saved experiment using load_model and load_experiment function available in all modules of PyCaret.
